# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/
# Out:
# checkpoint	 img		       LICENSE	    __pycache__       samples
# dataset		 jupyter_generator.py  local.ipynb  README.md
# Generator.ipynb  jupyter_main.py       main.ipynb   requirements.txt
# generator.py	 kogpt2		       main.py	    runs

# %%
# !ls

# %%
# !pip install -r /content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 348kB 4.2MB/s
# ...
#      |████████████████████████████████| 55.0MB 57kB/s
# ...
#      |████████████████████████████████| 1.1MB 59.7MB/s
# ...
#      |████████████████████████████████| 481kB 62.4MB/s
# ...
#      |████████████████████████████████| 317kB 61.5MB/s
# ...
#      |████████████████████████████████| 102kB 13.8MB/s
# ...
#      |████████████████████████████████| 3.1MB 58.0MB/s
# ...
#      |████████████████████████████████| 890kB 60.6MB/s
# ...
#      |████████████████████████████████| 7.0MB 52.7MB/s
# ...
#      |████████████████████████████████| 71kB 11.0MB/s
# ...
#   Created wheel for gluonnlp: filename=gluonnlp-0.10.0-cp36-cp36m-linux_x86_64.whl size=588520 sha256=ed2be8321e4ef6ba47a038228dfe6db7515b24faaa56759daf59d094922fe32b
#   Stored in directory: /root/.cache/pip/wheels/37/65/52/63032864a0f31a08b9a88569f803b5bafac8abd207fd7f7534
# ...

# %%
import os
import sys
sys.path.append('/content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/')
logs_base_dir = "runs"

# %%
from jupyter_main import main

# %%
ctx= 'cuda'
cachedir='~/kogpt2/'
load_path = '/content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/checkpoint/KoGPT2_checkpoint_296000.tar'
save_path = '/content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/checkpoint/'
data_file_path = '/content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/dataset/All_make_lyrics_dataset.txt'

# %% [markdown]
# # 모델 학습 시작

# %%
with open(save_path + 'KoGPT2_checkpoint_' + str(142) + '.tar', 'w') as f :
  f.write("가자")
f.close()

# %%
# !curl ipecho.net/plain
# Out:
# 34.73.6.200

# %%
#%load_ext tensorboard
#%tensorboard --logdir='./gdrive/My Drive/KoGPT2-FineTuning/runs'

# %%
# LOG_DIR = './gdrive/My Drive/KoGPT2-FineTuning/runs/'

# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# import os
# if not os.path.exists(LOG_DIR):
#   os.makedirs(LOG_DIR)
  
# get_ipython().system_raw(
#     'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
#     .format('./gdrive/My Drive/KoGPT2-FineTuning/runs'))

# get_ipython().system_raw('./ngrok http 6006 &')

# !curl -s http://localhost:4040/api/tunnels | python3 -c \
#     "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
main(load_path = load_path, data_file_path = data_file_path, save_path = save_path, summary_url = '/content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/runs/2020-05-01-new/', text_size = 1000, new = 1)
# Out:
# [██████████████████████████████████████████████████]
# [██████████████████████████████████████████████████]
# count 0 :  /content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/checkpoint/KoGPT2_checkpoint_296000.tar
# using cached model
# tokenizer start
# tokenizer ending
# (2, 16)
# KoGPT-2 Transfer Learning Start
# epoch no.0 train no.0  loss = 7.67627 avg_loss = 7.67627
# to_tokens: ['▁이', '<unk>', '운드', '해', '</s>']
# 사랑해</s>
# epoch no.10 train no.10  loss = 3.40997 avg_loss = 4.97882
# to_tokens: ['▁이', '<unk>', '천', '하는', '</s>']
# 사랑해</s>
# epoch no.20 train no.20  loss = 2.10432 avg_loss = 3.82636
# to_tokens: ['▁', '<unk>', '직', '해', '셔', '▁사람', '<unk>', '</s>']
# 사랑하는 이</s>
# epoch no.30 train no.30  loss = 1.14002 avg_loss = 3.00510
# to_tokens: ['▁', '▁', '▁', '해', '시다', '당', '</s>']
# 사랑합니다</s>
# epoch no.40 train no.40  loss = 0.44340 avg_loss = 2.36037
# to_tokens: ['▁', '[', '▁', '해']
# 사랑</s>
# ...

# %% [markdown]
# # 이제 부터는 관련 연구들

# %%
# !pip install kss

# %%
text = "사랑한다 <|endoftext|> [Verse 1: J-Hope] 힙합이란 것은 원래 그런 거지 원래 그런 거지 원래 그런 거지 원래 그런 거지 뭐, 그냥 그런 거지 뭐, 그냥 그런 거지 뭐, 그냥 그런 거지 뭐, 그냥 그런 거지 뭐, 그냥 그런 거지 뭐, 그냥 그런 거지 뭐 [Verse 2: Suga] 뭐 어쩌겠어 그딴 게 어<unk> Hangul [Verse 3: RM, Suga] 그래 내가 뭐 틀린 말했어 내가 뭐 거짓말했어 이길 수 있을까 이 기적 아닌 기적을 우리가 만든 걸까 (No) 난 여기 있었고 니가 내게 다가와준 거야 I do believe your galaxy 듣고 싶어 너의 멜로디 너의 은하수의 별들은 너의 하늘을 과연 어떻게 수놓을지 나의 절망 끝에 결국 내가 널 찾았음을 잊지마 넌 절벽 끝에 서 있던 내 마지막 이유야 Live [Pre-Chorus: Jin, RM] 나의 Daydream Daydream Daydream Daydream Daydream Daydream Last Daydream Daydream Daydream Daydream</s>"

# %%
import kss
for sent in kss.split_sentences(text):
    print(sent)

# %%
s = "회사 동료 분들과 다녀왔는데 분위기도 좋고 음식도 맛있었어요 다만, 강남 토끼정이 강남 쉑쉑버거 골목길로 쭉 올라가야 하는데 다들 쉑쉑버거의 유혹에 넘어갈 뻔 했답니다 강남역 맛집 토끼정의 외부 모습."
for sent in kss.split_sentences(s):
    print(sent)

# %%
# !pip install hanspell

# %%
test = []
for sent in kss.split_sentences(text):
    test.append(sent)

test = "\n".join(test)

print(test)

# %%
import hanspell
from hanspell import spell_checker
result = spell_checker.check(test)
result.as_dict()
