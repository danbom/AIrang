# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/requirements.txt

# %%
import os
import sys
sys.path.append('/content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/')
logs_base_dir = "runs"

# %%
from jupyter_main import main

# %%
main(load_path = "./checkpoint/KoGPT2_checkpoint_60000.tar")
# Out:
# using cached model
# using cached model
# count 0 :  ./checkpoint/KoGPT2_checkpoint_60000.tar
# using cached model
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7475633db4f1> in <module>()
# ----> 1 main(load_path = "./checkpoint/KoGPT2_checkpoint_60000.tar")
#
# /content/drive/MyDrive/GitHub/KoGPT2-Lyrics-Generation-FineTuning-Version1/jupyter_main.py in main(epoch, save_path, load_path, data_file_path, batch_size, summary_url, new, text_size)
#     115         sentencepieceTokenizer = SentencepieceTokenizer(tok_path)
#     116
# --> 117         dataset = Read_Dataset(data_file_path, vocab, sentencepieceTokenizer)
#     118         data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
#     119
#
# ...
